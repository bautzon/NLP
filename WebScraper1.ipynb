# %% [markdown]
# <a href="https://colab.research.google.com/github/bautzon/NLP/blob/main/WebScraper1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
import bs4 as bs

# %%
source = urllib.request.urlopen('https://www.reddit.com/r/gaming/').read()
soup = bs.BeautifulSoup(source,'html5lib')

for i in soup.findAll('h1'):
  print(i)
# Out:
# <h1 class="_2yYPPW47QxD4lFQTKpfpLQ">r/gaming</h1>
